# %%
from get_images import get_image

coords = (59.933443, 10.788159)
zoom=19

get_image(coords, topath='predict/test', zoom=zoom, verbose=False)

# %%
from IPython.display import Image
Image(filename=filepath)
